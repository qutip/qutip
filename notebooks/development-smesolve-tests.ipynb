# %% [markdown]
# ## Development notebook: Tests for QuTiP's stochastic master equation solver
#
# <h3 style="color: red">Warning: Experimental!</h3>
#
# In this notebook we test the qutip stochastic master equation solver (smesolve) with a few textbook examples taken from the book Quantum Optics, by Walls and Milburn, section 6.7.

# %% [markdown]
# <style>
# .rendered_html {
#     font-size: 125%;
#     font-family: Liberation Serif;
# }
#
# .rendered_html h1{
#     font-family: Liberation Sans;
#     margin: 0 0;
# }
#
# .rendered_html h2{
#     font-family: Liberation Sans;
#     margin: 0 0;
# }
#
# .input_prompt {
#     font-size: 100%;
#     font-family: Liberation Mono;
# }
#
# .CodeMirror-lines {
#     font-size: 100%;
#     font-family: Liberation Mono;
# }
#
# .output_area {
#     font-size: 100%;
#     font-family: Liberation Mono;
# }
#
# #ipython-main-app {
#     padding-left: 50px;
# }
# </style>

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
from qutip import *
from qutip.cyQ.spmatfuncs import spmv, cy_expect_rho_vec

# %% [markdown]
# ## Photo-count detection

# %% [markdown]
# ### Theory
#
# Stochastic master equation in Milburn's formulation
#
# $\displaystyle d\rho(t) = dN(t) \mathcal{G}[a] \rho(t) - dt \gamma \mathcal{H}[a^\dagger a] \rho(t)$
#
# where
#
# $\displaystyle \mathcal{G}[A] \rho = \frac{A\rho A^\dagger}{\mathrm{Tr}[A\rho A^\dagger]} - \rho$
#
# $\displaystyle \mathcal{H}[A] \rho = A\rho + \rho A^\dagger - \mathrm{Tr}[A\rho + \rho A^\dagger] \rho $
#
# and $dN(t)$ is a Poisson distributed increment with $E[dN(t)] = \gamma \langle a^\dagger a\rangle (t)$.

# %% [markdown]
# ### Formulation in QuTiP
#
# In QuTiP we write the stochastic master equation on the form (in the interaction picture, with no deterministic dissipation):
#
# $\displaystyle d\rho(t) = D_{1}[A]\rho(t) dt + D_{2}[A]\rho(t) dW$
#
# where $A = \sqrt{\gamma} a$, so we can identify
#
# $\displaystyle D_{1}[A]\rho(t) = - \gamma \mathcal{H}[a^\dagger a] \rho(t)
# = -\gamma \left( a^\dagger a\rho + \rho a^\dagger a - \mathrm{Tr}[a^\dagger a\rho + \rho a^\dagger a] \rho \right)
# = -\left( A^\dagger A\rho + \rho A^\dagger A - \mathrm{Tr}[A^\dagger A\rho + \rho A^\dagger A] \rho \right)$
#
# $\displaystyle D_{2}[A]\rho(t) = \mathcal{G}[a] \rho = \frac{A\rho A^\dagger}{\mathrm{Tr}[A\rho A^\dagger]} - \rho$
#
# and
#
# $dW = dN(t)$
#
# and $A = \sqrt{\gamma} a$ is the collapse operator including the rate of the process as a coefficient in the operator.

# %% [markdown]
# ### Reference solution: deterministic master equation

# %%
N = 15
w0 = 0.5 * 2 * pi
times = linspace(0, 15, 150)
gamma = 0.15

# %%
a = destroy(N)

# %%
H = w0 * a.dag() * a

# %%
rho0 = fock(N, 5)

# %%
c_ops = [sqrt(gamma) * a]

# %%
e_ops = [a.dag() * a, a + a.dag()]

# %%
result_ref = mesolve(H, rho0, times, c_ops, e_ops)

# %%
plot_expectation_values(result_ref);

# %% [markdown]
# ### Solve using stochastic master equation

# %%
# The argument A in the d1 and d2 callback functions is a list with the following
# precomputed superoperators, where c is the stochastic collapse operator given
# to the solver (called once for each operator, if more than one is given)
#
#     A[0] = spre(c)
#     A[1] = spost(c)
#     A[2] = spre(c.dag())
#     A[3] = spost(c.dag())
#     A[4] = spre(n)
#     A[5] = spost(n)
#     A[6] = (spre(c) * spost(c.dag())
#     A[7] = lindblad_dissipator(c)

# %% [markdown]
# $\displaystyle D_{1}[a, \rho] = -\gamma \left( a^\dagger a\rho + \rho a^\dagger a - \mathrm{Tr}[a^\dagger a\rho + \rho a^\dagger a] \right)
# \rightarrow - (\{A^\dagger A\}_L + \{A^\dagger A\}_R)\rho_v + \mathrm{E}[(\{A^\dagger A\}_L + \{A^\dagger A\}_R)\rho_v]$

# %%
def d1_rho_func(A, rho_vec):
    n_sum = A[4] + A[5]
    return - n_sum * rho_vec + cy_expect_rho_vec(n_sum, rho_vec) * rho_vec

# %% [markdown]
# $\displaystyle D_{2}[A, \rho(t)] = \frac{A\rho A^\dagger}{\mathrm{Tr}[A\rho A^\dagger]} - \rho
# \rightarrow \frac{A_LA^\dagger_R \rho_v}{\mathrm{E}[A_LA^\dagger_R \rho_v]} - \rho_v$

# %%
def d2_rho_func(A, rho_vec):
    e1 = cy_expect_rho_vec(A[6], rho_vec) + 1e-16  # add a small number to avoid division by zero
    return [(A[6] * rho_vec) / e1 - rho_vec]

# %%
result = smesolve(H, rho0, times, c_ops=[], sc_ops=c_ops, e_ops=e_ops, 
                  ntraj=5, nsubsteps=100, d1=d1_rho_func, d2=d2_rho_func,
                  distribution='poisson', store_measurement=True)
# Out:
# smesolve
# smesolve_generic
# Completed:  0.0%. Elapsed time:   0.00s. Est. remaining time: 00:00:00:00.
# Completed: 20.0%. Elapsed time:   7.58s. Est. remaining time: 00:00:00:30.
# Completed: 40.0%. Elapsed time:  15.17s. Est. remaining time: 00:00:00:22.
# Completed: 60.0%. Elapsed time:  22.75s. Est. remaining time: 00:00:00:15.
# Completed: 80.0%. Elapsed time:  30.32s. Est. remaining time: 00:00:00:07.
# Elapsed time:  37.92s

# %%
plot_expectation_values([result, result_ref]);
# Out:
# /usr/local/lib/python3.3/dist-packages/numpy/core/numeric.py:341: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
fig, ax = subplots()

for m in result.measurement:
    ax.plot(times, m)

# %% [markdown]
# #### Solve problem again, this time with a specified noise (from previous run)

# %%
result = smesolve(H, rho0, times, c_ops=[], sc_ops=c_ops, e_ops=e_ops, 
                  ntraj=5, nsubsteps=100, d1=d1_rho_func, d2=d2_rho_func,
                  distribution='poisson', store_measurement=True, noise=result.noise)
# Out:
# smesolve
# smesolve_generic
# Completed:  0.0%. Elapsed time:   0.00s. Est. remaining time: 00:00:00:00.
# Completed: 20.0%. Elapsed time:   6.89s. Est. remaining time: 00:00:00:27.
# Completed: 40.0%. Elapsed time:  13.78s. Est. remaining time: 00:00:00:20.
# Completed: 60.0%. Elapsed time:  20.67s. Est. remaining time: 00:00:00:13.
# Completed: 80.0%. Elapsed time:  27.55s. Est. remaining time: 00:00:00:06.
# Elapsed time:  34.45s

# %%
plot_expectation_values([result, result_ref]);

# %%
fig, ax = subplots()

for m in result.measurement:
    ax.plot(times, m)

# %% [markdown]
# #### Using QuTiP built-in photo-current detection functions for $D_1$ and $D_2$

# %%
result = smesolve(H, rho0, times, [], c_ops, e_ops, ntraj=5, nsubsteps=100, method='photocurrent', store_measurement=True)
# Out:
# smesolve
# smesolve_generic
# Completed:  0.0%. Elapsed time:   0.00s. Est. remaining time: 00:00:00:00.
# Completed: 20.0%. Elapsed time:   6.24s. Est. remaining time: 00:00:00:24.
# Completed: 40.0%. Elapsed time:  12.47s. Est. remaining time: 00:00:00:18.
# Completed: 60.0%. Elapsed time:  18.71s. Est. remaining time: 00:00:00:12.
# Completed: 80.0%. Elapsed time:  24.94s. Est. remaining time: 00:00:00:06.
# Elapsed time:  31.17s

# %%
plot_expectation_values([result, result_ref]);

# %% [markdown]
# #### Solve problem again, this time with a specified noise (from previous run)

# %%
result = smesolve(H, rho0, times, c_ops=[], sc_ops=c_ops, e_ops=e_ops, ntraj=5, nsubsteps=100,
                  method='photocurrent', store_measurement=True, noise=result.noise)
# Out:
# smesolve
# smesolve_generic
# Completed:  0.0%. Elapsed time:   0.00s. Est. remaining time: 00:00:00:00.
# Completed: 20.0%. Elapsed time:   5.53s. Est. remaining time: 00:00:00:22.
# Completed: 40.0%. Elapsed time:  11.05s. Est. remaining time: 00:00:00:16.
# Completed: 60.0%. Elapsed time:  16.59s. Est. remaining time: 00:00:00:11.
# Completed: 80.0%. Elapsed time:  22.11s. Est. remaining time: 00:00:00:05.
# Elapsed time:  27.63s

# %%
plot_expectation_values([result, result_ref]);

# %%
fig, ax = subplots()

for m in result.measurement:
    ax.plot(times, m)

# %% [markdown]
# ## Homodyne detection

# %% [markdown]
# ### Theory
#
# Stochastic master equation for homodyne in Milburn's formulation
#
# $\displaystyle d\rho(t) = -i[H, \rho(t)]dt + \gamma\mathcal{D}[a]\rho(t) dt + dW(t) \sqrt{\gamma} \mathcal{H}[a] \rho(t)$
#
# where $\mathcal{D}$ is the standard Lindblad dissipator superoperator, and $\mathcal{H}$ is defined as above,
# and $dW(t)$ is a normal distributed increment with $E[dW(t)] = \sqrt{dt}$.
#
# In QuTiP format we have:
#
# $\displaystyle d\rho(t) = -i[H, \rho(t)]dt +  D_{1}[A]\rho(t) dt + D_{2}[A]\rho(t) dW$
#
# where $A = \sqrt{\gamma} a$, so we can identify

# %% [markdown]
# $\displaystyle D_{1}[A]\rho(t) = \gamma \mathcal{D}[a]\rho(t) = \mathcal{D}[A]\rho(t)$

# %%
def d1_rho_func(A, rho_vec):
    return A[7] * rho_vec

# %% [markdown]
# $\displaystyle D_{2}[A]\rho(t) = \sqrt{\gamma} \mathcal{H}[a]\rho(t)
# = A\rho + \rho A^\dagger - \mathrm{Tr}[A\rho + \rho A^\dagger] \rho
# \rightarrow (A_L +  A_R^\dagger)\rho_v - \mathrm{Tr}[(A_L +  A_R^\dagger)\rho_v] \rho_v$

# %%
def d2_rho_func(A, rho_vec):
    n_sum = A[0] + A[3]
    e1 = cy_expect_rho_vec(n_sum, rho_vec)
    return [n_sum * rho_vec - e1 * rho_vec]

# %%
result = smesolve(H, rho0, times, [], c_ops, e_ops, 
                  ntraj=5, nsubsteps=100, d1=d1_rho_func, d2=d2_rho_func,
                  distribution='normal', store_measurement=True)
# Out:
# smesolve
# smesolve_generic
# Completed:  0.0%. Elapsed time:   0.00s. Est. remaining time: 00:00:00:00.
# Completed: 20.0%. Elapsed time:   5.25s. Est. remaining time: 00:00:00:20.
# Completed: 40.0%. Elapsed time:  10.51s. Est. remaining time: 00:00:00:15.
# Completed: 60.0%. Elapsed time:  15.78s. Est. remaining time: 00:00:00:10.
# Completed: 80.0%. Elapsed time:  21.04s. Est. remaining time: 00:00:00:05.
# Elapsed time:  26.31s

# %%
plot_expectation_values([result, result_ref]);

# %%
fig, ax = subplots()

for m in result.measurement:
    ax.plot(times, m)
    
ax.plot(times, array(result.measurement).mean(axis=0), 'k', lw=5);

# %% [markdown]
# #### Solve problem again, this time with a specified noise (from previous run)

# %%
result = smesolve(H, rho0, times, [], c_ops, e_ops, 
                  ntraj=5, nsubsteps=100, d1=d1_rho_func, d2=d2_rho_func,
                  distribution='normal', store_measurement=True, noise=result.noise)
# Out:
# smesolve
# smesolve_generic
# Completed:  0.0%. Elapsed time:   0.00s. Est. remaining time: 00:00:00:00.
# Completed: 20.0%. Elapsed time:   5.28s. Est. remaining time: 00:00:00:21.
# Completed: 40.0%. Elapsed time:  10.54s. Est. remaining time: 00:00:00:15.
# Completed: 60.0%. Elapsed time:  15.81s. Est. remaining time: 00:00:00:10.
# Completed: 80.0%. Elapsed time:  21.09s. Est. remaining time: 00:00:00:05.
# Elapsed time:  26.37s

# %%
plot_expectation_values([result, result_ref]);

# %%
fig, ax = subplots()

for m in result.measurement:
    ax.plot(times, m)
    
ax.plot(times, array(result.measurement).mean(axis=0), 'k', lw=5);

# %% [markdown]
# #### Using QuTiP built-in homodyne detection functions for $D_1$ and $D_2$

# %%
result = smesolve(H, rho0, times, [], c_ops, e_ops, ntraj=5, nsubsteps=100, method='homodyne', store_measurement=True)
# Out:
# smesolve
# smesolve_generic
# Completed:  0.0%. Elapsed time:   0.00s. Est. remaining time: 00:00:00:00.
# Completed: 20.0%. Elapsed time:   5.07s. Est. remaining time: 00:00:00:20.
# Completed: 40.0%. Elapsed time:  10.16s. Est. remaining time: 00:00:00:15.
# Completed: 60.0%. Elapsed time:  15.24s. Est. remaining time: 00:00:00:10.
# Completed: 80.0%. Elapsed time:  20.35s. Est. remaining time: 00:00:00:05.
# Elapsed time:  25.43s

# %%
plot_expectation_values([result, result_ref]);

# %%
fig, ax = subplots()

for m in result.measurement:
    ax.plot(times, m)
    
ax.plot(times, array(result.measurement).mean(axis=0), 'k', lw=5);

# %% [markdown]
# #### Solve problem again, this time with a specified noise (from previous run)

# %%
result = smesolve(H, rho0, times, [], c_ops, e_ops, ntraj=5, nsubsteps=100, method='homodyne', store_measurement=True, noise=result.noise)
# Out:
# smesolve
# smesolve_generic
# Completed:  0.0%. Elapsed time:   0.00s. Est. remaining time: 00:00:00:00.
# Completed: 20.0%. Elapsed time:   5.05s. Est. remaining time: 00:00:00:20.
# Completed: 40.0%. Elapsed time:  10.10s. Est. remaining time: 00:00:00:15.
# Completed: 60.0%. Elapsed time:  15.14s. Est. remaining time: 00:00:00:10.
# Completed: 80.0%. Elapsed time:  20.19s. Est. remaining time: 00:00:00:05.
# Elapsed time:  25.24s

# %%
plot_expectation_values([result, result_ref]);

# %%
fig, ax = subplots()

for m in result.measurement:
    ax.plot(times, m)
    
ax.plot(times, array(result.measurement).mean(axis=0), 'k', lw=5);

# %% [markdown]
# ## Heterodyne detection

# %% [markdown]
# Stochastic master equation for heterodyne in Milburn's formulation
#
# $\displaystyle d\rho(t) = -i[H, \rho(t)]dt + \gamma\mathcal{D}[a]\rho(t) dt + \frac{1}{\sqrt{2}} dW_1(t) \sqrt{\gamma} \mathcal{H}[a] \rho(t) + \frac{1}{\sqrt{2}} dW_2(t) \sqrt{\gamma} \mathcal{H}[-ia] \rho(t)$
#
# where $\mathcal{D}$ is the standard Lindblad dissipator superoperator, and $\mathcal{H}$ is defined as above,
# and $dW_i(t)$ is a normal distributed increment with $E[dW_i(t)] = \sqrt{dt}$.
#
# In QuTiP format we have:
#
# $\displaystyle d\rho(t) = -i[H, \rho(t)]dt +  D_{1}[A]\rho(t) dt + D_{2}^{(1)}[A]\rho(t) dW_1 + D_{2}^{(2)}[A]\rho(t) dW_2$
#
# where $A = \sqrt{\gamma} a$, so we can identify

# %% [markdown]
# $\displaystyle D_{1}[A]\rho = \gamma \mathcal{D}[a]\rho = \mathcal{D}[A]\rho$

# %%
def d1_rho_func(A, rho_vec):
    return spmv(A[7].data, A[7].indices, A[7].indptr, rho_vec)

# %% [markdown]
# $D_{2}^{(1)}[A]\rho = \frac{1}{\sqrt{2}} \sqrt{\gamma} \mathcal{H}[a] \rho =
# \frac{1}{\sqrt{2}} \mathcal{H}[A] \rho =
# \frac{1}{\sqrt{2}}(A\rho + \rho A^\dagger - \mathrm{Tr}[A\rho + \rho A^\dagger] \rho)
# \rightarrow \frac{1}{\sqrt{2}} \left\{(A_L +  A_R^\dagger)\rho_v - \mathrm{Tr}[(A_L +  A_R^\dagger)\rho_v] \rho_v\right\}$
#
# $D_{2}^{(2)}[A]\rho = \frac{1}{\sqrt{2}} \sqrt{\gamma} \mathcal{H}[-ia] \rho
# = \frac{1}{\sqrt{2}} \mathcal{H}[-iA] \rho =
# \frac{-i}{\sqrt{2}}(A\rho - \rho A^\dagger - \mathrm{Tr}[A\rho - \rho A^\dagger] \rho)
# \rightarrow \frac{-i}{\sqrt{2}} \left\{(A_L -  A_R^\dagger)\rho_v - \mathrm{Tr}[(A_L - A_R^\dagger)\rho_v] \rho_v\right\}$

# %%
def d2_rho_func(A, rho_vec):

    n_sum = A[0] + A[3]
    e1 = cy_expect_rho_vec(n_sum, rho_vec)
    drho1 = n_sum * rho_vec - e1 * rho_vec

    n_sum = A[0] - A[3]
    e1 = cy_expect_rho_vec(n_sum, rho_vec)
    drho2 = n_sum * rho_vec - e1 * rho_vec

    return [1.0/sqrt(2) * drho1, -1.0j/sqrt(2) * drho2]

# %%
result = smesolve(H, rho0, times, [], c_ops, e_ops, 
                  ntraj=5, nsubsteps=100, d1=d1_rho_func, d2=d2_rho_func, d2_len=2,
                  distribution='normal', store_measurement=True)
# Out:
# smesolve
# smesolve_generic
# Completed:  0.0%. Elapsed time:   0.00s. Est. remaining time: 00:00:00:00.
# Completed: 20.0%. Elapsed time:   9.34s. Est. remaining time: 00:00:00:37.
# Completed: 40.0%. Elapsed time:  18.70s. Est. remaining time: 00:00:00:28.
# Completed: 60.0%. Elapsed time:  28.04s. Est. remaining time: 00:00:00:18.
# Completed: 80.0%. Elapsed time:  37.38s. Est. remaining time: 00:00:00:09.
# Elapsed time:  46.72s

# %%
plot_expectation_values([result, result_ref]);

# %%
fig, ax = subplots()

for m in result.measurement:
    ax.plot(times, m)
    
ax.plot(times, array(result.measurement).mean(axis=0), 'k', lw=5);

# %% [markdown]
# #### Using QuTiP built-in homodyne detection functions for $D_1$ and $D_2$

# %%
result = smesolve(H, rho0, times, [], c_ops, e_ops, ntraj=5, nsubsteps=100, method='heterodyne', store_measurement=True)
# Out:
# smesolve
# smesolve_generic
# Completed:  0.0%. Elapsed time:   0.00s. Est. remaining time: 00:00:00:00.
# Completed: 20.0%. Elapsed time:   9.14s. Est. remaining time: 00:00:00:36.
# Completed: 40.0%. Elapsed time:  18.27s. Est. remaining time: 00:00:00:27.
# Completed: 60.0%. Elapsed time:  27.48s. Est. remaining time: 00:00:00:18.
# Completed: 80.0%. Elapsed time:  36.63s. Est. remaining time: 00:00:00:09.
# Elapsed time:  45.78s

# %%
plot_expectation_values([result, result_ref]);

# %%
fig, ax = subplots()

for m in result.measurement:
    ax.plot(times, m)
    
ax.plot(times, array(result.measurement).mean(axis=0), 'k', lw=5);

# %% [markdown]
# #### Solve problem again, this time with a specified noise (from previous run)

# %%
result = smesolve(H, rho0, times, [], c_ops, e_ops, ntraj=5, nsubsteps=100, method='heterodyne', store_measurement=True, noise=result.noise)
# Out:
# smesolve
# smesolve_generic
# Completed:  0.0%. Elapsed time:   0.00s. Est. remaining time: 00:00:00:00.
# Completed: 20.0%. Elapsed time:   9.19s. Est. remaining time: 00:00:00:36.
# Completed: 40.0%. Elapsed time:  18.36s. Est. remaining time: 00:00:00:27.
# Completed: 60.0%. Elapsed time:  27.52s. Est. remaining time: 00:00:00:18.
# Completed: 80.0%. Elapsed time:  36.69s. Est. remaining time: 00:00:00:09.
# Elapsed time:  45.84s

# %%
plot_expectation_values([result, result_ref]);

# %%
fig, ax = subplots()

for m in result.measurement:
    ax.plot(times, m)
    
ax.plot(times, array(result.measurement).mean(axis=0), 'k', lw=5);

# %% [markdown]
# ### Software version

# %%
from qutip.ipynbtools import version_table

version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>OS</td><td>posix [linux]</td></tr><tr><td>SciPy</td><td>0.13.0.dev-d74fd00</td></tr><tr><td>IPython</td><td>1.0.dev</td></tr><tr><td>Cython</td><td>0.19.1</td></tr><tr><td>matplotlib</td><td>1.4.x</td></tr><tr><td>Numpy</td><td>1.8.0.dev-75cdf3d</td></tr><tr><td>Python</td><td>3.3.1 (default, Apr 17 2013, 22:30:32)
# [GCC 4.7.3]</td></tr><tr><td>QuTiP</td><td>2.3.0.dev-ad4db81</td></tr><tr><td colspan='2'>Tue Jun 11 14:39:15 2013 JST</td></tr></table>
